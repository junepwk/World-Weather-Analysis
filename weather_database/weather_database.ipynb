# %%
# Import the dependencies
import pandas as pd
import numpy as np
import requests
from citipy import citipy 
from config import weather_api_key

# %%
# Create a set of 2,000 random latitudes and longitudes
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Pack latitudes and longitudes as pairs by zipping them
lat_lngs = zip(lats, lngs)

# Add the coordinates to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# url for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | bandarbeyla
# Processing Record 5 of Set 1 | saldanha
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | ulsteinvik
# Processing Record 11 of Set 1 | maha sarakham
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | chikoy
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | rio grande
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | srednekolymsk
# Processing Record 20 of Set 1 | codrington
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | orocue
# Processing Record 24 of Set 1 | gat
# Processing Record 25 of Set 1 | katobu
# Processing Record 26 of Set 1 | santa rosa
# Processing Record 27 of Set 1 | aklavik
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | okhotsk
# Processing Record 30 of Set 1 | mareeba
# Processing Record 31 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 1 | ambilobe
# Processing Record 35 of Set 1 | gallup
# Processing Record 36 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | chippewa falls
# Processing Record 40 of Set 1 | hambantota
# Processing Record 41 of Set 1 | melfi
# Processing Record 42 of Set 1 | sunndalsora
# Processing Record 43 of Set 1 | gemena
# Processing Record 44 of Set 1 | kaniama
# Processing Record 45 of Set 1 | chapais
# Processing Record 46 of Set 1 | harnosand
# Processing Record 47 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 1 | ocampo
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | kurgan
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | touros
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | tralee
# Processing Record 5 of Set 2 | viedma
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | praya
# Processing Record 12 of Set 2 | port pirie
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | mecca
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | poltavka
# Processing Record 19 of Set 2 | puerto penasco
# Processing Record 20 of Set 2 | talnakh
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 2 | ahipara
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | fairbanks
# Processing Record 28 of Set 2 | ust-omchug
# Processing Record 29 of Set 2 | we
# City not found. Skipping...
# Processing Record 30 of Set 2 | hay river
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | san cristobal
# Processing Record 33 of Set 2 | bodden town
# Processing Record 34 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | bukavu
# Processing Record 42 of Set 2 | coihaique
# Processing Record 43 of Set 2 | shenjiamen
# Processing Record 44 of Set 2 | kilindoni
# Processing Record 45 of Set 2 | sao joao da barra
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 50 of Set 2 | quatre cocos
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | albion
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | omboue
# Processing Record 5 of Set 3 | antofagasta
# Processing Record 6 of Set 3 | santa isabel
# Processing Record 7 of Set 3 | torbay
# Processing Record 8 of Set 3 | zatoka
# Processing Record 9 of Set 3 | chapleau
# Processing Record 10 of Set 3 | jackson
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | betlitsa
# Processing Record 13 of Set 3 | houma
# Processing Record 14 of Set 3 | batemans bay
# Processing Record 15 of Set 3 | manglaur
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | severo-yeniseyskiy
# Processing Record 18 of Set 3 | batagay
# Processing Record 19 of Set 3 | jistebnice
# Processing Record 20 of Set 3 | north bend
# Processing Record 21 of Set 3 | pangnirtung
# Processing Record 22 of Set 3 | saint-pierre
# Processing Record 23 of Set 3 | severnoye
# Processing Record 24 of Set 3 | terre haute
# Processing Record 25 of Set 3 | moreira sales
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | mar del plata
# Processing Record 28 of Set 3 | lasa
# Processing Record 29 of Set 3 | port blair
# Processing Record 30 of Set 3 | sisimiut
# Processing Record 31 of Set 3 | keningau
# Processing Record 32 of Set 3 | hermanus
# Processing Record 33 of Set 3 | huilong
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | mana
# Processing Record 36 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 3 | labuhan
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | hovd
# Processing Record 41 of Set 3 | pevek
# Processing Record 42 of Set 3 | xushan
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | birjand
# Processing Record 46 of Set 3 | yatou
# Processing Record 47 of Set 3 | omsukchan
# Processing Record 48 of Set 3 | konevo
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 4 | jining
# Processing Record 2 of Set 4 | agadez
# Processing Record 3 of Set 4 | san patricio
# Processing Record 4 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 4 | sinnamary
# Processing Record 6 of Set 4 | natal
# Processing Record 7 of Set 4 | bengkulu
# Processing Record 8 of Set 4 | arlit
# Processing Record 9 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | taitung
# Processing Record 12 of Set 4 | chifeng
# Processing Record 13 of Set 4 | lavrentiya
# Processing Record 14 of Set 4 | nizhniy tsasuchey
# Processing Record 15 of Set 4 | liniere
# City not found. Skipping...
# Processing Record 16 of Set 4 | butaritari
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | kloulklubed
# Processing Record 21 of Set 4 | minusinsk
# Processing Record 22 of Set 4 | guiratinga
# Processing Record 23 of Set 4 | balakhta
# Processing Record 24 of Set 4 | dwarka
# Processing Record 25 of Set 4 | palma del rio
# Processing Record 26 of Set 4 | aloleng
# Processing Record 27 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 28 of Set 4 | sangar
# Processing Record 29 of Set 4 | alvorada
# Processing Record 30 of Set 4 | cairns
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | havre-saint-pierre
# Processing Record 33 of Set 4 | olga
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | yar-sale
# Processing Record 37 of Set 4 | singaraja
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | senno
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | kon tum
# Processing Record 42 of Set 4 | bengkalis
# City not found. Skipping...
# Processing Record 43 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 4 | townsville
# Processing Record 45 of Set 4 | bowen
# Processing Record 46 of Set 4 | sheltozero
# Processing Record 47 of Set 4 | terney
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | bathurst
# Processing Record 50 of Set 4 | san quintin
# Processing Record 1 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 5 | karakol
# Processing Record 3 of Set 5 | makakilo city
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | gornyye klyuchi
# Processing Record 6 of Set 5 | katangli
# Processing Record 7 of Set 5 | kakching
# Processing Record 8 of Set 5 | halifax
# Processing Record 9 of Set 5 | san pedro
# Processing Record 10 of Set 5 | iwaki
# Processing Record 11 of Set 5 | katsuura
# Processing Record 12 of Set 5 | rani
# Processing Record 13 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 5 | agara
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | emerald
# Processing Record 17 of Set 5 | vila franca do campo
# Processing Record 18 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 5 | victoria
# Processing Record 20 of Set 5 | nemuro
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | mnogovershinnyy
# Processing Record 23 of Set 5 | katherine
# Processing Record 24 of Set 5 | beira
# Processing Record 25 of Set 5 | reims
# Processing Record 26 of Set 5 | padang
# Processing Record 27 of Set 5 | macomb
# Processing Record 28 of Set 5 | lahad datu
# Processing Record 29 of Set 5 | liberal
# Processing Record 30 of Set 5 | rocha
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | necochea
# Processing Record 33 of Set 5 | asau
# Processing Record 34 of Set 5 | nishihara
# Processing Record 35 of Set 5 | tukrah
# Processing Record 36 of Set 5 | porto novo
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | quimper
# Processing Record 39 of Set 5 | vaitape
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | kalmunai
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | dalianwan
# Processing Record 44 of Set 5 | pafos
# Processing Record 45 of Set 5 | yashkul
# Processing Record 46 of Set 5 | upernavik
# Processing Record 47 of Set 5 | dharchula
# Processing Record 48 of Set 5 | karratha
# Processing Record 49 of Set 5 | camana
# Processing Record 50 of Set 5 | souillac
# Processing Record 1 of Set 6 | ritchie
# Processing Record 2 of Set 6 | bantou
# Processing Record 3 of Set 6 | kaitangata
# Processing Record 4 of Set 6 | riviere-au-renard
# Processing Record 5 of Set 6 | vao
# Processing Record 6 of Set 6 | iqaluit
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | evans
# Processing Record 9 of Set 6 | vilyuysk
# Processing Record 10 of Set 6 | ternate
# Processing Record 11 of Set 6 | ferkessedougou
# Processing Record 12 of Set 6 | kabo
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | nouakchott
# Processing Record 15 of Set 6 | erenhot
# Processing Record 16 of Set 6 | vernon
# Processing Record 17 of Set 6 | kaeo
# Processing Record 18 of Set 6 | kruisfontein
# Processing Record 19 of Set 6 | mucurapo
# Processing Record 20 of Set 6 | avera
# Processing Record 21 of Set 6 | norman wells
# Processing Record 22 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | teguise
# Processing Record 26 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 6 | ayagoz
# Processing Record 28 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 29 of Set 6 | bedong
# Processing Record 30 of Set 6 | dudinka
# Processing Record 31 of Set 6 | novikovo
# Processing Record 32 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | kefamenanu
# Processing Record 35 of Set 6 | cockburn town
# Processing Record 36 of Set 6 | mahajanga
# Processing Record 37 of Set 6 | mchinji
# Processing Record 38 of Set 6 | yeysk
# Processing Record 39 of Set 6 | qostanay
# Processing Record 40 of Set 6 | alofi
# Processing Record 41 of Set 6 | mankera
# Processing Record 42 of Set 6 | ust-kuyga
# Processing Record 43 of Set 6 | oksfjord
# Processing Record 44 of Set 6 | wad madani
# Processing Record 45 of Set 6 | canyon
# Processing Record 46 of Set 6 | lincoln
# Processing Record 47 of Set 6 | zhuanghe
# Processing Record 48 of Set 6 | kerman
# Processing Record 49 of Set 6 | maracaju
# Processing Record 50 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 7 | raudeberg
# Processing Record 2 of Set 7 | markala
# Processing Record 3 of Set 7 | nanakuli
# Processing Record 4 of Set 7 | grand gaube
# Processing Record 5 of Set 7 | sloboda
# Processing Record 6 of Set 7 | virginia beach
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | verkhnevilyuysk
# Processing Record 9 of Set 7 | naryan-mar
# Processing Record 10 of Set 7 | los alamos
# Processing Record 11 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 7 | maridi
# Processing Record 13 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 7 | alta floresta
# Processing Record 15 of Set 7 | marsa matruh
# Processing Record 16 of Set 7 | diplo
# Processing Record 17 of Set 7 | yuryevets
# Processing Record 18 of Set 7 | goure
# Processing Record 19 of Set 7 | olafsvik
# Processing Record 20 of Set 7 | yulara
# Processing Record 21 of Set 7 | nelson bay
# Processing Record 22 of Set 7 | baldovinesti
# Processing Record 23 of Set 7 | ous
# Processing Record 24 of Set 7 | lorengau
# Processing Record 25 of Set 7 | georgetown
# Processing Record 26 of Set 7 | roald
# Processing Record 27 of Set 7 | komsomolskiy
# Processing Record 28 of Set 7 | nantucket
# Processing Record 29 of Set 7 | lagoa
# Processing Record 30 of Set 7 | cesme
# Processing Record 31 of Set 7 | patiya
# Processing Record 32 of Set 7 | uyuni
# Processing Record 33 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 7 | budogoshch
# Processing Record 35 of Set 7 | provideniya
# Processing Record 36 of Set 7 | monrovia
# Processing Record 37 of Set 7 | saint-paul-les-dax
# Processing Record 38 of Set 7 | oistins
# Processing Record 39 of Set 7 | mehamn
# Processing Record 40 of Set 7 | nicoya
# Processing Record 41 of Set 7 | angoche
# Processing Record 42 of Set 7 | sobolevo
# Processing Record 43 of Set 7 | tabou
# Processing Record 44 of Set 7 | upington
# Processing Record 45 of Set 7 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 7 | nizwa
# Processing Record 47 of Set 7 | siguiri
# Processing Record 48 of Set 7 | sterling
# Processing Record 49 of Set 7 | hirara
# Processing Record 50 of Set 7 | atar
# Processing Record 1 of Set 8 | dillon
# Processing Record 2 of Set 8 | san lawrenz
# Processing Record 3 of Set 8 | qaqortoq
# Processing Record 4 of Set 8 | faanui
# Processing Record 5 of Set 8 | husavik
# Processing Record 6 of Set 8 | balabac
# Processing Record 7 of Set 8 | stromness
# Processing Record 8 of Set 8 | puro
# Processing Record 9 of Set 8 | valdez
# Processing Record 10 of Set 8 | alamosa
# Processing Record 11 of Set 8 | serik
# Processing Record 12 of Set 8 | kahului
# Processing Record 13 of Set 8 | faya
# Processing Record 14 of Set 8 | meadow lake
# Processing Record 15 of Set 8 | arya
# Processing Record 16 of Set 8 | caravelas
# Processing Record 17 of Set 8 | dhidhdhoo
# Processing Record 18 of Set 8 | yerbogachen
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | merauke
# Processing Record 21 of Set 8 | junin
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | berlevag
# Processing Record 24 of Set 8 | lyuban
# Processing Record 25 of Set 8 | augusta
# Processing Record 26 of Set 8 | portland
# Processing Record 27 of Set 8 | edzell
# Processing Record 28 of Set 8 | dawlatabad
# Processing Record 29 of Set 8 | broome
# Processing Record 30 of Set 8 | panama city
# Processing Record 31 of Set 8 | jalalabad
# Processing Record 32 of Set 8 | vanino
# Processing Record 33 of Set 8 | homer
# Processing Record 34 of Set 8 | tigil
# Processing Record 35 of Set 8 | umm lajj
# Processing Record 36 of Set 8 | south hill
# Processing Record 37 of Set 8 | port elizabeth
# Processing Record 38 of Set 8 | pemba
# Processing Record 39 of Set 8 | kavaratti
# Processing Record 40 of Set 8 | hasaki
# Processing Record 41 of Set 8 | aguimes
# Processing Record 42 of Set 8 | waddan
# Processing Record 43 of Set 8 | visby
# Processing Record 44 of Set 8 | talcahuano
# Processing Record 45 of Set 8 | havelock
# Processing Record 46 of Set 8 | lata
# Processing Record 47 of Set 8 | isiro
# Processing Record 48 of Set 8 | northam
# Processing Record 49 of Set 8 | dohar
# Processing Record 50 of Set 8 | dera ismail khan
# Processing Record 1 of Set 9 | krasnoselkup
# Processing Record 2 of Set 9 | tateyama
# Processing Record 3 of Set 9 | callaway
# Processing Record 4 of Set 9 | santa lucia
# Processing Record 5 of Set 9 | itaituba
# Processing Record 6 of Set 9 | sitka
# Processing Record 7 of Set 9 | foumban
# Processing Record 8 of Set 9 | gladstone
# Processing Record 9 of Set 9 | denpasar
# Processing Record 10 of Set 9 | berdigestyakh
# Processing Record 11 of Set 9 | tir pol
# City not found. Skipping...
# Processing Record 12 of Set 9 | rabo de peixe
# Processing Record 13 of Set 9 | afua
# Processing Record 14 of Set 9 | wagga wagga
# Processing Record 15 of Set 9 | waingapu
# Processing Record 16 of Set 9 | arinos
# Processing Record 17 of Set 9 | boa vista
# Processing Record 18 of Set 9 | buala
# Processing Record 19 of Set 9 | vanimo
# Processing Record 20 of Set 9 | pine bluff
# Processing Record 21 of Set 9 | ossora
# Processing Record 22 of Set 9 | dingle
# Processing Record 23 of Set 9 | springbok
# Processing Record 24 of Set 9 | kupang
# Processing Record 25 of Set 9 | lillesand
# Processing Record 26 of Set 9 | khatanga
# Processing Record 27 of Set 9 | atherton
# Processing Record 28 of Set 9 | manggar
# Processing Record 29 of Set 9 | carnarvon
# Processing Record 30 of Set 9 | richards bay
# Processing Record 31 of Set 9 | kuching
# Processing Record 32 of Set 9 | uspenka
# Processing Record 33 of Set 9 | hofn
# Processing Record 34 of Set 9 | cayenne
# Processing Record 35 of Set 9 | ciudad bolivar
# Processing Record 36 of Set 9 | calvinia
# Processing Record 37 of Set 9 | harindanga
# Processing Record 38 of Set 9 | chara
# Processing Record 39 of Set 9 | hobyo
# Processing Record 40 of Set 9 | grindavik
# Processing Record 41 of Set 9 | sioux lookout
# Processing Record 42 of Set 9 | sakaiminato
# Processing Record 43 of Set 9 | banda aceh
# Processing Record 44 of Set 9 | awbari
# Processing Record 45 of Set 9 | urozhaynoye
# Processing Record 46 of Set 9 | ewa beach
# Processing Record 47 of Set 9 | sola
# Processing Record 48 of Set 9 | sorland
# Processing Record 49 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 9 | marawi
# Processing Record 1 of Set 10 | ketchikan
# Processing Record 2 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 3 of Set 10 | belmonte
# Processing Record 4 of Set 10 | cleethorpes
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | daru
# Processing Record 7 of Set 10 | ouadda
# Processing Record 8 of Set 10 | kushmurun
# Processing Record 9 of Set 10 | san ramon
# Processing Record 10 of Set 10 | krasnopavlivka
# Processing Record 11 of Set 10 | goderich
# Processing Record 12 of Set 10 | hamilton
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | road town
# Processing Record 15 of Set 10 | sladkovo
# Processing Record 16 of Set 10 | half moon bay
# Processing Record 17 of Set 10 | vardo
# Processing Record 18 of Set 10 | yeppoon
# Processing Record 19 of Set 10 | maxixe
# Processing Record 20 of Set 10 | kimberley
# Processing Record 21 of Set 10 | gimli
# Processing Record 22 of Set 10 | port-gentil
# Processing Record 23 of Set 10 | phan thiet
# Processing Record 24 of Set 10 | qarqin
# Processing Record 25 of Set 10 | mbengwi
# Processing Record 26 of Set 10 | kulykiv
# Processing Record 27 of Set 10 | laguna
# Processing Record 28 of Set 10 | kompaniyivka
# Processing Record 29 of Set 10 | kalga
# Processing Record 30 of Set 10 | kismayo
# Processing Record 31 of Set 10 | miyako
# Processing Record 32 of Set 10 | san jose
# Processing Record 33 of Set 10 | sunrise manor
# Processing Record 34 of Set 10 | stawell
# Processing Record 35 of Set 10 | le port
# Processing Record 36 of Set 10 | ndiekro
# City not found. Skipping...
# Processing Record 37 of Set 10 | poum
# Processing Record 38 of Set 10 | grand-lahou
# Processing Record 39 of Set 10 | pedernales
# Processing Record 40 of Set 10 | mount gambier
# Processing Record 41 of Set 10 | mutis
# Processing Record 42 of Set 10 | rawlins
# Processing Record 43 of Set 10 | quixeramobim
# Processing Record 44 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 45 of Set 10 | kasongo
# Processing Record 46 of Set 10 | lae
# Processing Record 47 of Set 10 | wanaka
# Processing Record 48 of Set 10 | peleduy
# Processing Record 49 of Set 10 | bagan
# Processing Record 50 of Set 10 | arman
# Processing Record 1 of Set 11 | okoneshnikovo
# Processing Record 2 of Set 11 | shimoda
# Processing Record 3 of Set 11 | filingue
# Processing Record 4 of Set 11 | ayan
# Processing Record 5 of Set 11 | cartagena
# Processing Record 6 of Set 11 | brae
# Processing Record 7 of Set 11 | tiznit
# Processing Record 8 of Set 11 | luwuk
# Processing Record 9 of Set 11 | deputatskiy
# Processing Record 10 of Set 11 | flinders
# Processing Record 11 of Set 11 | san luis
# Processing Record 12 of Set 11 | marsaxlokk
# Processing Record 13 of Set 11 | envira
# Processing Record 14 of Set 11 | mangai
# Processing Record 15 of Set 11 | calvia
# Processing Record 16 of Set 11 | chicama
# Processing Record 17 of Set 11 | columbus
# Processing Record 18 of Set 11 | celestun
# Processing Record 19 of Set 11 | cowra
# Processing Record 20 of Set 11 | pundaguitan
# Processing Record 21 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 22 of Set 11 | jumla
# Processing Record 23 of Set 11 | kokopo
# Processing Record 24 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 11 | te anau
# Processing Record 26 of Set 11 | balch springs
# Processing Record 27 of Set 11 | bambanglipuro
# Processing Record 28 of Set 11 | nanortalik
# Processing Record 29 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 11 | bhandaria
# Processing Record 31 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 11 | santa isabel do rio negro
# Processing Record 33 of Set 11 | beringovskiy
# Processing Record 34 of Set 11 | radishchevo
# Processing Record 35 of Set 11 | port augusta
# Processing Record 36 of Set 11 | hami
# Processing Record 37 of Set 11 | honningsvag
# Processing Record 38 of Set 11 | muros
# Processing Record 39 of Set 11 | oeiras
# Processing Record 40 of Set 11 | paamiut
# Processing Record 41 of Set 11 | prince rupert
# Processing Record 42 of Set 11 | villablino
# Processing Record 43 of Set 11 | kenitra
# Processing Record 44 of Set 11 | mitsamiouli
# Processing Record 45 of Set 11 | calabozo
# Processing Record 46 of Set 11 | saleilua
# City not found. Skipping...
# Processing Record 47 of Set 11 | zhicheng
# Processing Record 48 of Set 11 | imbituba
# Processing Record 49 of Set 11 | oltenesti
# Processing Record 50 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 12 | qasigiannguit
# Processing Record 2 of Set 12 | gidole
# Processing Record 3 of Set 12 | bojnurd
# Processing Record 4 of Set 12 | cherskiy
# Processing Record 5 of Set 12 | sagaing
# Processing Record 6 of Set 12 | mahebourg
# Processing Record 7 of Set 12 | dunmore
# Processing Record 8 of Set 12 | asbury park
# Processing Record 9 of Set 12 | anadyr
# Processing Record 10 of Set 12 | hare bay
# Processing Record 11 of Set 12 | monduli
# Processing Record 12 of Set 12 | doha
# Processing Record 13 of Set 12 | nipawin
# Processing Record 14 of Set 12 | medak
# Processing Record 15 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 12 | ulaanbaatar
# Processing Record 17 of Set 12 | saint-augustin
# Processing Record 18 of Set 12 | usinsk
# Processing Record 19 of Set 12 | portage
# Processing Record 20 of Set 12 | aksarka
# Processing Record 21 of Set 12 | korla
# Processing Record 22 of Set 12 | angol
# Processing Record 23 of Set 12 | wajima
# Processing Record 24 of Set 12 | tumarbong
# Processing Record 25 of Set 12 | egvekinot
# Processing Record 26 of Set 12 | pagudpud
# Processing Record 27 of Set 12 | victor harbor
# Processing Record 28 of Set 12 | beian
# Processing Record 29 of Set 12 | merritt island
# Processing Record 30 of Set 12 | sovetskiy
# Processing Record 31 of Set 12 | igrim
# Processing Record 32 of Set 12 | martapura
# Processing Record 33 of Set 12 | revda
# Processing Record 34 of Set 12 | vostok
# Processing Record 35 of Set 12 | comodoro rivadavia
# Processing Record 36 of Set 12 | mastic beach
# Processing Record 37 of Set 12 | bjornevatn
# Processing Record 38 of Set 12 | pingliang
# Processing Record 39 of Set 12 | kamenka
# Processing Record 40 of Set 12 | strabychovo
# Processing Record 41 of Set 12 | trat
# Processing Record 42 of Set 12 | maragogi
# Processing Record 43 of Set 12 | garachine
# Processing Record 44 of Set 12 | auki
# Processing Record 45 of Set 12 | vestmannaeyjar
# Processing Record 46 of Set 12 | kabinda
# Processing Record 47 of Set 12 | san vicente
# Processing Record 48 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 12 | pitimbu
# Processing Record 50 of Set 12 | san
# Processing Record 1 of Set 13 | vrangel
# Processing Record 2 of Set 13 | alexandria
# Processing Record 3 of Set 13 | orlovskiy
# Processing Record 4 of Set 13 | calamar
# Processing Record 5 of Set 13 | eldoret
# Processing Record 6 of Set 13 | abu dhabi
# Processing Record 7 of Set 13 | hit
# Processing Record 8 of Set 13 | ancona
# Processing Record 9 of Set 13 | san buenaventura
# Processing Record 10 of Set 13 | awjilah
# Processing Record 11 of Set 13 | huarmey
# Processing Record 12 of Set 13 | benton harbor
# Processing Record 13 of Set 13 | sabha
# Processing Record 14 of Set 13 | abu samrah
# Processing Record 15 of Set 13 | eenhana
# Processing Record 16 of Set 13 | bonavista
# Processing Record 17 of Set 13 | morondava
# Processing Record 18 of Set 13 | ibimirim
# Processing Record 19 of Set 13 | margate
# Processing Record 20 of Set 13 | ola
# Processing Record 21 of Set 13 | sorong
# Processing Record 22 of Set 13 | boo
# Processing Record 23 of Set 13 | burnie
# Processing Record 24 of Set 13 | nago
# Processing Record 25 of Set 13 | clarence town
# Processing Record 26 of Set 13 | saint-joseph
# Processing Record 27 of Set 13 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 28 of Set 13 | chegdomyn
# Processing Record 29 of Set 13 | sechura
# Processing Record 30 of Set 13 | thinadhoo
# Processing Record 31 of Set 13 | touho
# Processing Record 32 of Set 13 | lazarev
# Processing Record 33 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 34 of Set 13 | linhares
# Processing Record 35 of Set 13 | konstantinovskiy
# Processing Record 36 of Set 13 | dzilam gonzalez
# Processing Record 37 of Set 13 | sembe
# Processing Record 38 of Set 13 | kytlym
# City not found. Skipping...
# Processing Record 39 of Set 13 | luanda
# Processing Record 40 of Set 13 | kosonsoy
# Processing Record 41 of Set 13 | caraballeda
# Processing Record 42 of Set 13 | mangrol
# Processing Record 43 of Set 13 | carballo
# Processing Record 44 of Set 13 | emilio carranza
# Processing Record 45 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 13 | college
# Processing Record 47 of Set 13 | blind river
# Processing Record 48 of Set 13 | teregova
# Processing Record 49 of Set 13 | sungairaya
# Processing Record 50 of Set 13 | pacific grove
# Processing Record 1 of Set 14 | chumikan
# Processing Record 2 of Set 14 | nabire
# Processing Record 3 of Set 14 | bogorodskoye
# Processing Record 4 of Set 14 | shintomi
# Processing Record 5 of Set 14 | pineville
# Processing Record 6 of Set 14 | moose factory
# Processing Record 7 of Set 14 | hauterive
# Processing Record 8 of Set 14 | kirakira
# Processing Record 9 of Set 14 | mayo
# Processing Record 10 of Set 14 | ibotirama
# Processing Record 11 of Set 14 | fomboni
# Processing Record 12 of Set 14 | beloha
# Processing Record 13 of Set 14 | antigonish
# Processing Record 14 of Set 14 | simpang
# Processing Record 15 of Set 14 | jaguarari
# Processing Record 16 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 14 | albacete
# Processing Record 18 of Set 14 | agogo
# Processing Record 19 of Set 14 | escanaba
# Processing Record 20 of Set 14 | santa fe
# Processing Record 21 of Set 14 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 14 | heinola
# Processing Record 23 of Set 14 | port hedland
# Processing Record 24 of Set 14 | norman
# Processing Record 25 of Set 14 | ucluelet
# Processing Record 26 of Set 14 | rawson
# Processing Record 27 of Set 14 | ulladulla
# Processing Record 28 of Set 14 | pascagoula
# Processing Record 29 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 30 of Set 14 | uinskoye
# Processing Record 31 of Set 14 | yunhe
# Processing Record 32 of Set 14 | los llanos de aridane
# Processing Record 33 of Set 14 | lagos
# Processing Record 34 of Set 14 | mayor pablo lagerenza
# Processing Record 35 of Set 14 | belaya gora
# Processing Record 36 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 14 | voyinka
# Processing Record 38 of Set 14 | gunjur
# Processing Record 39 of Set 14 | namibe
# Processing Record 40 of Set 14 | belyy yar
# Processing Record 41 of Set 14 | ribas do rio pardo
# Processing Record 42 of Set 14 | ahuimanu
# Processing Record 43 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 44 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 46 of Set 14 | teknaf
# Processing Record 47 of Set 14 | shingu
# Processing Record 48 of Set 14 | tarakan
# Processing Record 49 of Set 14 | taft
# Processing Record 50 of Set 14 | rathkeale
# Processing Record 1 of Set 15 | bhim tal
# Processing Record 2 of Set 15 | chiredzi
# Processing Record 3 of Set 15 | castle rock
# Processing Record 4 of Set 15 | berdyuzhye
# City not found. Skipping...
# Processing Record 5 of Set 15 | bay city
# Processing Record 6 of Set 15 | talah
# City not found. Skipping...
# Processing Record 7 of Set 15 | marzuq
# Processing Record 8 of Set 15 | las guacamayas
# Processing Record 9 of Set 15 | cabedelo
# Processing Record 10 of Set 15 | vytegra
# Processing Record 11 of Set 15 | sao felix do xingu
# Processing Record 12 of Set 15 | vestmanna
# Processing Record 13 of Set 15 | sisophon
# Processing Record 14 of Set 15 | tanda
# Processing Record 15 of Set 15 | flin flon
# Processing Record 16 of Set 15 | coquimbo
# Processing Record 17 of Set 15 | conde
# Processing Record 18 of Set 15 | high prairie
# Processing Record 19 of Set 15 | nhulunbuy
# Processing Record 20 of Set 15 | praia
# Processing Record 21 of Set 15 | ukiah
# Processing Record 22 of Set 15 | orlik
# Processing Record 23 of Set 15 | el balyana
# City not found. Skipping...
# Processing Record 24 of Set 15 | anicuns
# Processing Record 25 of Set 15 | bayan
# Processing Record 26 of Set 15 | adrar
# Processing Record 27 of Set 15 | toporu
# Processing Record 28 of Set 15 | vangaindrano
# Processing Record 29 of Set 15 | waiuku
# Processing Record 30 of Set 15 | aswan
# Processing Record 31 of Set 15 | kang
# Processing Record 32 of Set 15 | pital
# Processing Record 33 of Set 15 | ostrovnoy
# Processing Record 34 of Set 15 | kambove
# Processing Record 35 of Set 15 | piste
# Processing Record 36 of Set 15 | cochrane
# Processing Record 37 of Set 15 | gorom-gorom
# Processing Record 38 of Set 15 | athabasca
# Processing Record 39 of Set 15 | tucuma
# Processing Record 40 of Set 15 | liverpool
# Processing Record 41 of Set 15 | north myrtle beach
# Processing Record 42 of Set 15 | barkly west
# Processing Record 43 of Set 15 | riyadh
# Processing Record 44 of Set 15 | taber
# Processing Record 45 of Set 15 | iquique
# Processing Record 46 of Set 15 | presidencia roque saenz pena
# Processing Record 47 of Set 15 | tadine
# Processing Record 48 of Set 15 | gambela
# Processing Record 49 of Set 15 | jinchang
# Processing Record 50 of Set 15 | ruteng
# Processing Record 1 of Set 16 | mineros
# Processing Record 2 of Set 16 | suao
# City not found. Skipping...
# Processing Record 3 of Set 16 | nieuw amsterdam
# Processing Record 4 of Set 16 | guane
# Processing Record 5 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 16 | axim
# Processing Record 7 of Set 16 | nome
# Processing Record 8 of Set 16 | dunedin
# Processing Record 9 of Set 16 | nueva germania
# Processing Record 10 of Set 16 | port hardy
# Processing Record 11 of Set 16 | port moresby
# Processing Record 12 of Set 16 | raiganj
# Processing Record 13 of Set 16 | nouadhibou
# Processing Record 14 of Set 16 | dukat
# Processing Record 15 of Set 16 | havoysund
# Processing Record 16 of Set 16 | matelandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Sao Filipe      CV  14.8961  -24.4956     76.87        67          91
# 1        Rikitea      PF -23.1203 -134.9692     75.70        79         100
# 2        Mataura      NZ -46.1927  168.8643     41.99        95          82
# 3    Bandarbeyla      SO   9.4942   50.8122     79.27        86          36
# 4       Saldanha      ZA -33.0117   17.9442     57.25        40           6
# 5    New Norfolk      AU -42.7826  147.0587     43.57        76         100
# 6     Vila Velha      BR -20.3297  -40.2925     75.94        87          40
# 7      Geraldton      AU -28.7667  114.6000     46.81        87           0
# 8     Ulsteinvik      NO  62.3432    5.8487     62.11        93         100
# 9  Maha Sarakham      TH  16.3333  103.6667     80.19        88         100
#
#    Wind Speed Current Description
# 0       13.00     overcast clouds
# 1       11.05     overcast clouds
# 2        1.70       broken clouds
# 3       24.34    scattered clouds
# 4       10.92           clear sky
# 5        1.99     overcast clouds
# 6        1.01    scattered clouds
# 7        7.29           clear sky
# 8        1.99     overcast clouds
# 9        4.07       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
